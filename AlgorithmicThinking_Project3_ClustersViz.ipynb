# %%
import alg_clusters_matplotlib as acm
import alg_project3_solution as aps
import alg_project3_viz as viz

import importlib

importlib.reload(acm)
importlib.reload(aps)
importlib.reload(viz)
# Out:
# <module 'alg_project3_viz' from '/content/alg_project3_viz.py'>

# %%
viz.run_example()
# Out:
# Loaded 111 data points
# Displaying 9 hierarchical clusters
